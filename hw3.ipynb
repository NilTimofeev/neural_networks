# %% [markdown]
# 1. Постройте нейронную сеть (берем несложную полносвязную сеть, меняем число слоев, число нейронов, типы активации, тип оптимизатора) на датасете from sklearn.datasets import load_boston.
#
# 2. Постройте 10-15 вариантов разных нейронных сетей и сведите результаты их работы в таблицу. Опишите, какого результата вы добились от нейросети? Что помогло вам улучшить ее точность?

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Flatten, Dense
from tensorflow.keras.models import Sequential, Model
from keras import backend

from sklearn.datasets import load_boston
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
boston_dataset = load_boston()
boston_dataset.keys()
# Out:
# dict_keys(['data', 'target', 'feature_names', 'DESCR', 'filename'])

# %%
X = pd.DataFrame(boston_dataset.data, columns = boston_dataset.feature_names)
y = boston_dataset.target
X.head(2)
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
#
#    PTRATIO      B  LSTAT
# 0     15.3  396.9   4.98
# 1     17.8  396.9   9.14

# %%
X = StandardScaler().fit_transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state=1)
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((379, 13), (379,), (127, 13), (127,))

# %%
# коэффициент детерминации для используемых моделей
def det_coeff(y_true, y_pred):
    SS_res =  backend.sum(backend.square(y_true-y_pred))
    SS_tot = backend.sum(backend.square(y_true - backend.mean(y_true)))
    return (1 - SS_res / (SS_tot + backend.epsilon()))

# %%
# %%time
res = pd.DataFrame(columns=['n', 'layers', 'optimizer', 'activation', 'det_coeff', 'val_det_coeff'])

n_list = [5, 10, 20, 50]
layers_list = [3, 5, 7, 10]
optims = ['adam', 'RMSprop']
f_activ = ['relu', 'sigmoid', 'tanh']

# sp = 0
# fig = plt.figure(figsize=(120,20))
# plt.subplots_adjust(hspace=0.5)

for n in n_list:
    for layers in layers_list:
        for optim in optims:
            for f in f_activ:
#                 sp +=1
                
                model = Sequential([
                    Dense(n, input_shape=(13,), activation=f)
                ])
                for _ in range(layers - 1):
                    model.add(Dense(n, activation=f))
                model.add(Dense(1))
                
                model.compile(optimizer=optim, loss='mse', metrics=[det_coeff])
                
                history = model.fit(X_train, y_train,
                                    epochs=15,
                                    batch_size=10,
                                    verbose=0,
                                    validation_data=(X_test, y_test))
                
                train_loss, train_metric = model.evaluate(X_train, y_train)
                test_loss, test_metric = model.evaluate(X_test, y_test)
                
#                 ax = fig.add_subplot(48, 2, sp)
#                 ax.plot(history.history['val_det_coeff'], label=f'val {optim} {round(test_metric,2)}')
#                 ax.plot(history.history['det_coeff'], label=f'train {optim} {round(train_metric,2)}')
#                 ax.legend()
#                 ax.set_xlabel('epoch')
#                 ax.set_ylabel('det_coeff')
#                 ax.set(title = f'Ошибка сети от эпох при {n} нейронах и функции активации {f}')
                
                res = res.append({'n': n, 'layers': layers, 'optimizer': optim, 'activation': f,
                                  'det_coeff': train_metric, 'val_det_coeff': test_metric}, ignore_index=True)
# plt.show()
# Out:
# 12/12 [==============================] - 0s 2ms/step - loss: 34.2755 - det_coeff: 0.5479
# 4/4 [==============================] - 0s 2ms/step - loss: 37.1746 - det_coeff: 0.6178
# 12/12 [==============================] - 0s 2ms/step - loss: 403.5283 - det_coeff: -4.5216
# 4/4 [==============================] - 0s 2ms/step - loss: 450.6878 - det_coeff: -3.7889
# 12/12 [==============================] - 0s 1ms/step - loss: 328.1540 - det_coeff: -3.4567
# 4/4 [==============================] - 0s 2ms/step - loss: 372.1771 - det_coeff: -2.9442
# 12/12 [==============================] - 0s 2ms/step - loss: 45.9689 - det_coeff: 0.4015
# 4/4 [==============================] - 0s 2ms/step - loss: 49.3505 - det_coeff: 0.4964
# 12/12 [==============================] - 0s 2ms/step - loss: 467.7470 - det_coeff: -5.4311
# 4/4 [==============================] - 0s 2ms/step - loss: 517.5823 - det_coeff: -4.5084
# 12/12 [==============================] - 0s 2ms/step - loss: 384.8626 - det_coeff: -4.2574
# 4/4 [==============================] - 0s 2ms/step - loss: 431.2575 - det_coeff: -3.5800
# 12/12 [==============================] - 0s 3ms/step - loss: 41.3842 - det_coeff: 0.4430
# 4/4 [==============================] - 0s 2ms/step - loss: 48.4354 - det_coeff: 0.4921
# 12/12 [==============================] - 0s 2ms/step - loss: 409.8029 - det_coeff: -4.6102
# 4/4 [==============================] - 0s 2ms/step - loss: 457.3121 - det_coeff: -3.8603
# 12/12 [==============================] - 0s 2ms/step - loss: 326.2273 - det_coeff: -3.4293
# 4/4 [==============================] - 0s 2ms/step - loss: 370.2560 - det_coeff: -2.9239
# 12/12 [==============================] - 0s 3ms/step - loss: 32.4916 - det_coeff: 0.5766
# 4/4 [==============================] - 0s 2ms/step - loss: 32.3093 - det_coeff: 0.6567
# 12/12 [==============================] - 0s 2ms/step - loss: 373.9351 - det_coeff: -4.1029
# 4/4 [==============================] - 0s 2ms/step - loss: 419.9238 - det_coeff: -3.4582
# 12/12 [==============================] - 0s 2ms/step - loss: 337.6712 - det_coeff: -3.5908
# 4/4 [==============================] - 0s 2ms/step - loss: 382.0223 - det_coeff: -3.0506
# 12/12 [==============================] - 0s 2ms/step - loss: 36.1676 - det_coeff: 0.5128
# 4/4 [==============================] - 0s 2ms/step - loss: 39.1574 - det_coeff: 0.5902
# 12/12 [==============================] - 0s 2ms/step - loss: 423.9509 - det_coeff: -4.8105
# 4/4 [==============================] - 0s 2ms/step - loss: 472.0392 - det_coeff: -4.0187
# 12/12 [==============================] - 0s 2ms/step - loss: 319.0812 - det_coeff: -3.3286
# 4/4 [==============================] - 0s 2ms/step - loss: 362.5419 - det_coeff: -2.8412
# 12/12 [==============================] - 0s 2ms/step - loss: 47.3042 - det_coeff: 0.3482
# 4/4 [==============================] - 0s 2ms/step - loss: 50.4567 - det_coeff: 0.4800
# 12/12 [==============================] - 0s 1ms/step - loss: 398.1966 - det_coeff: -4.4460
# 4/4 [==============================] - 0s 2ms/step - loss: 445.2241 - det_coeff: -3.7303
# 12/12 [==============================] - 0s 3ms/step - loss: 332.7298 - det_coeff: -3.5211
# 4/4 [==============================] - 0s 3ms/step - loss: 376.8501 - det_coeff: -2.9950
# 12/12 [==============================] - 0s 2ms/step - loss: 24.6046 - det_coeff: 0.6662
# 4/4 [==============================] - 0s 2ms/step - loss: 18.7373 - det_coeff: 0.8049
# 12/12 [==============================] - 0s 2ms/step - loss: 385.5480 - det_coeff: -4.2671
# 4/4 [==============================] - 0s 3ms/step - loss: 432.0389 - det_coeff: -3.5885
# 12/12 [==============================] - 0s 2ms/step - loss: 350.4779 - det_coeff: -3.7715
# 4/4 [==============================] - 0s 2ms/step - loss: 395.4197 - det_coeff: -3.1947
# 12/12 [==============================] - 0s 2ms/step - loss: 553.3555 - det_coeff: -6.6466
# 4/4 [==============================] - 0s 2ms/step - loss: 606.2556 - det_coeff: -5.4625
# 12/12 [==============================] - 0s 2ms/step - loss: 437.4654 - det_coeff: -5.0020
# 4/4 [==============================] - 0s 2ms/step - loss: 486.0944 - det_coeff: -4.1698
# 12/12 [==============================] - 0s 2ms/step - loss: 338.8537 - det_coeff: -3.6075
# 4/4 [==============================] - 0s 2ms/step - loss: 383.2608 - det_coeff: -3.0639
# 12/12 [==============================] - 0s 1ms/step - loss: 26.3957 - det_coeff: 0.6560
# 4/4 [==============================] - 0s 2ms/step - loss: 25.2754 - det_coeff: 0.7436
# 12/12 [==============================] - 0s 1ms/step - loss: 313.7454 - det_coeff: -3.2535
# 4/4 [==============================] - 0s 2ms/step - loss: 356.9175 - det_coeff: -2.7807
# 12/12 [==============================] - 0s 1ms/step - loss: 216.7031 - det_coeff: -1.8911
# 4/4 [==============================] - 0s 2ms/step - loss: 254.3760 - det_coeff: -1.6785
# 12/12 [==============================] - 0s 1ms/step - loss: 32.0197 - det_coeff: 0.5705
# 4/4 [==============================] - 0s 2ms/step - loss: 28.5912 - det_coeff: 0.7106
# 12/12 [==============================] - 0s 2ms/step - loss: 310.3938 - det_coeff: -3.2062
# 4/4 [==============================] - 0s 2ms/step - loss: 353.4274 - det_coeff: -2.7432
# 12/12 [==============================] - 0s 1ms/step - loss: 282.6083 - det_coeff: -2.8152
# 4/4 [==============================] - 0s 2ms/step - loss: 324.2145 - det_coeff: -2.4291
# 12/12 [==============================] - 0s 1ms/step - loss: 18.4164 - det_coeff: 0.7545
# 4/4 [==============================] - 0s 2ms/step - loss: 18.7460 - det_coeff: 0.8076
# 12/12 [==============================] - 0s 2ms/step - loss: 447.4552 - det_coeff: -5.1435
# 4/4 [==============================] - 0s 2ms/step - loss: 496.4771 - det_coeff: -4.2815
# 12/12 [==============================] - 0s 1ms/step - loss: 214.6840 - det_coeff: -1.8627
# 4/4 [==============================] - 0s 2ms/step - loss: 252.4436 - det_coeff: -1.6578
# 12/12 [==============================] - 0s 2ms/step - loss: 23.0186 - det_coeff: 0.6957
# 4/4 [==============================] - 0s 2ms/step - loss: 26.1010 - det_coeff: 0.7280
# 12/12 [==============================] - 0s 2ms/step - loss: 286.7805 - det_coeff: -2.8738
# 4/4 [==============================] - 0s 2ms/step - loss: 328.6278 - det_coeff: -2.4766
# 12/12 [==============================] - 0s 2ms/step - loss: 251.4685 - det_coeff: -2.3779
# 4/4 [==============================] - 0s 2ms/step - loss: 291.3914 - det_coeff: -2.0763
# 12/12 [==============================] - 0s 2ms/step - loss: 22.0955 - det_coeff: 0.7109
# 4/4 [==============================] - 0s 2ms/step - loss: 21.0700 - det_coeff: 0.7840
# 12/12 [==============================] - 0s 2ms/step - loss: 343.7834 - det_coeff: -3.6770
# 4/4 [==============================] - 0s 3ms/step - loss: 388.4189 - det_coeff: -3.1194
# 12/12 [==============================] - 0s 2ms/step - loss: 240.6822 - det_coeff: -2.2268
# 4/4 [==============================] - 0s 2ms/step - loss: 280.0016 - det_coeff: -1.9539
# 12/12 [==============================] - 0s 2ms/step - loss: 17.3375 - det_coeff: 0.7674
# 4/4 [==============================] - 0s 2ms/step - loss: 14.0288 - det_coeff: 0.8500
# 12/12 [==============================] - 0s 1ms/step - loss: 340.6235 - det_coeff: -3.6324
# 4/4 [==============================] - 0s 2ms/step - loss: 385.1128 - det_coeff: -3.0838
# 12/12 [==============================] - 0s 1ms/step - loss: 246.8700 - det_coeff: -2.3135
# 4/4 [==============================] - 0s 3ms/step - loss: 286.5282 - det_coeff: -2.0241
# 12/12 [==============================] - 0s 2ms/step - loss: 16.6127 - det_coeff: 0.7856
# 4/4 [==============================] - 0s 2ms/step - loss: 15.6487 - det_coeff: 0.8434
# 12/12 [==============================] - 0s 2ms/step - loss: 363.8113 - det_coeff: -3.9598
# 4/4 [==============================] - 0s 3ms/step - loss: 409.3536 - det_coeff: -3.3445
# 12/12 [==============================] - 0s 2ms/step - loss: 229.0466 - det_coeff: -2.0639
# 4/4 [==============================] - 0s 2ms/step - loss: 267.6441 - det_coeff: -1.8211
# 12/12 [==============================] - 0s 2ms/step - loss: 18.6037 - det_coeff: 0.7564
# 4/4 [==============================] - 0s 2ms/step - loss: 17.4185 - det_coeff: 0.8196
# 12/12 [==============================] - 0s 2ms/step - loss: 330.6672 - det_coeff: -3.4920
# 4/4 [==============================] - 0s 2ms/step - loss: 374.6901 - det_coeff: -2.9718
# 12/12 [==============================] - 0s 2ms/step - loss: 224.5203 - det_coeff: -2.0006
# 4/4 [==============================] - 0s 2ms/step - loss: 262.8372 - det_coeff: -1.7695
# 12/12 [==============================] - 0s 1ms/step - loss: 16.8797 - det_coeff: 0.7764
# 4/4 [==============================] - 0s 2ms/step - loss: 14.4863 - det_coeff: 0.8464
# 12/12 [==============================] - 0s 1ms/step - loss: 232.5572 - det_coeff: -2.1131
# 4/4 [==============================] - 0s 3ms/step - loss: 271.3416 - det_coeff: -1.8609
# 12/12 [==============================] - 0s 1ms/step - loss: 111.0642 - det_coeff: -0.4253
# 4/4 [==============================] - 0s 2ms/step - loss: 140.1491 - det_coeff: -0.4554
# 12/12 [==============================] - 0s 1ms/step - loss: 18.7561 - det_coeff: 0.7517
# 4/4 [==============================] - 0s 2ms/step - loss: 14.6636 - det_coeff: 0.8455
# 12/12 [==============================] - 0s 1ms/step - loss: 273.7809 - det_coeff: -2.6911
# 4/4 [==============================] - 0s 2ms/step - loss: 314.9422 - det_coeff: -2.3294
# 12/12 [==============================] - 0s 1ms/step - loss: 116.6821 - det_coeff: -0.5031
# 4/4 [==============================] - 0s 2ms/step - loss: 146.6980 - det_coeff: -0.5253
# 12/12 [==============================] - 0s 1ms/step - loss: 12.4099 - det_coeff: 0.8343
# 4/4 [==============================] - 0s 2ms/step - loss: 13.2493 - det_coeff: 0.8650
# 12/12 [==============================] - 0s 2ms/step - loss: 225.1479 - det_coeff: -2.0094
# 4/4 [==============================] - 0s 2ms/step - loss: 263.5034 - det_coeff: -1.7767
# 12/12 [==============================] - 0s 1ms/step - loss: 118.3565 - det_coeff: -0.5267
# 4/4 [==============================] - 0s 2ms/step - loss: 147.3200 - det_coeff: -0.5322
# 12/12 [==============================] - 0s 2ms/step - loss: 14.2334 - det_coeff: 0.8136
# 4/4 [==============================] - 0s 4ms/step - loss: 14.0221 - det_coeff: 0.8550
# 12/12 [==============================] - 0s 2ms/step - loss: 164.5444 - det_coeff: -1.1664
# 4/4 [==============================] - 0s 2ms/step - loss: 198.6337 - det_coeff: -1.0799
# 12/12 [==============================] - 0s 2ms/step - loss: 99.8034 - det_coeff: -0.2740
# 4/4 [==============================] - 0s 3ms/step - loss: 130.7918 - det_coeff: -0.3512
# 12/12 [==============================] - 0s 2ms/step - loss: 12.4519 - det_coeff: 0.8365
# 4/4 [==============================] - 0s 2ms/step - loss: 12.9806 - det_coeff: 0.8653
# 12/12 [==============================] - 0s 2ms/step - loss: 215.4314 - det_coeff: -1.8737
# 4/4 [==============================] - 0s 2ms/step - loss: 253.1734 - det_coeff: -1.6657
# 12/12 [==============================] - 0s 2ms/step - loss: 117.4713 - det_coeff: -0.5222
# 4/4 [==============================] - 0s 2ms/step - loss: 146.9188 - det_coeff: -0.5254
# 12/12 [==============================] - 0s 3ms/step - loss: 11.1161 - det_coeff: 0.8544
# 4/4 [==============================] - 0s 2ms/step - loss: 12.0358 - det_coeff: 0.8750
# 12/12 [==============================] - 0s 2ms/step - loss: 245.1146 - det_coeff: -2.2889
# 4/4 [==============================] - 0s 2ms/step - loss: 284.6709 - det_coeff: -2.0041
# 12/12 [==============================] - 0s 2ms/step - loss: 112.8120 - det_coeff: -0.4595
# 4/4 [==============================] - 0s 2ms/step - loss: 141.7326 - det_coeff: -0.4696
# 12/12 [==============================] - 0s 2ms/step - loss: 10.0854 - det_coeff: 0.8671
# 4/4 [==============================] - 0s 2ms/step - loss: 11.1882 - det_coeff: 0.8880
# 12/12 [==============================] - 0s 2ms/step - loss: 262.6682 - det_coeff: -2.5351
# 4/4 [==============================] - 0s 2ms/step - loss: 303.2212 - det_coeff: -2.2035
# 12/12 [==============================] - 0s 2ms/step - loss: 121.7785 - det_coeff: -0.5804
# 4/4 [==============================] - 0s 2ms/step - loss: 151.7932 - det_coeff: -0.5774
# 12/12 [==============================] - 0s 2ms/step - loss: 10.6635 - det_coeff: 0.8624
# 4/4 [==============================] - 0s 2ms/step - loss: 12.0535 - det_coeff: 0.8738
# 12/12 [==============================] - 0s 2ms/step - loss: 212.4725 - det_coeff: -1.8324
# 4/4 [==============================] - 0s 2ms/step - loss: 250.0232 - det_coeff: -1.6318
# 12/12 [==============================] - 0s 2ms/step - loss: 113.8039 - det_coeff: -0.4729
# 4/4 [==============================] - 0s 2ms/step - loss: 142.8522 - det_coeff: -0.4816
# 12/12 [==============================] - 0s 2ms/step - loss: 10.6802 - det_coeff: 0.8571
# 4/4 [==============================] - 0s 2ms/step - loss: 10.3048 - det_coeff: 0.8936
# 12/12 [==============================] - 0s 1ms/step - loss: 89.3480 - det_coeff: -0.1511
# 4/4 [==============================] - 0s 2ms/step - loss: 114.4343 - det_coeff: -0.1778
# 12/12 [==============================] - 0s 2ms/step - loss: 45.1724 - det_coeff: 0.4443
# 4/4 [==============================] - 0s 2ms/step - loss: 62.1437 - det_coeff: 0.3544
# 12/12 [==============================] - 0s 1ms/step - loss: 13.5335 - det_coeff: 0.8213
# 4/4 [==============================] - 0s 2ms/step - loss: 11.7415 - det_coeff: 0.8778
# 12/12 [==============================] - 0s 2ms/step - loss: 77.9712 - det_coeff: -0.0201
# 4/4 [==============================] - 0s 2ms/step - loss: 98.7570 - det_coeff: -0.0123
# 12/12 [==============================] - 0s 1ms/step - loss: 34.3222 - det_coeff: 0.5821
# 4/4 [==============================] - 0s 2ms/step - loss: 48.5224 - det_coeff: 0.5007
# 12/12 [==============================] - 0s 2ms/step - loss: 8.7146 - det_coeff: 0.8813
# 4/4 [==============================] - 0s 2ms/step - loss: 9.8714 - det_coeff: 0.8959
# 12/12 [==============================] - 0s 2ms/step - loss: 105.3302 - det_coeff: -0.3597
# 4/4 [==============================] - 0s 2ms/step - loss: 133.2193 - det_coeff: -0.3784
# 12/12 [==============================] - 0s 2ms/step - loss: 41.6981 - det_coeff: 0.4937
# 4/4 [==============================] - 0s 2ms/step - loss: 60.0233 - det_coeff: 0.3846
# 12/12 [==============================] - 0s 2ms/step - loss: 13.2318 - det_coeff: 0.8267
# 4/4 [==============================] - 0s 2ms/step - loss: 13.9369 - det_coeff: 0.8556
# 12/12 [==============================] - 0s 2ms/step - loss: 79.6456 - det_coeff: -0.0447
# 4/4 [==============================] - 0s 2ms/step - loss: 100.6773 - det_coeff: -0.0315
# 12/12 [==============================] - 0s 2ms/step - loss: 28.9147 - det_coeff: 0.6495
# 4/4 [==============================] - 0s 2ms/step - loss: 41.1719 - det_coeff: 0.5780
# 12/12 [==============================] - 0s 2ms/step - loss: 9.6360 - det_coeff: 0.8738
# 4/4 [==============================] - 0s 2ms/step - loss: 9.4124 - det_coeff: 0.9006
# 12/12 [==============================] - 0s 2ms/step - loss: 92.5047 - det_coeff: -0.1922
# 4/4 [==============================] - 0s 2ms/step - loss: 118.1874 - det_coeff: -0.2176
# 12/12 [==============================] - 0s 2ms/step - loss: 50.1611 - det_coeff: 0.3833
# 4/4 [==============================] - 0s 2ms/step - loss: 68.1056 - det_coeff: 0.2966
# 12/12 [==============================] - 0s 2ms/step - loss: 9.5976 - det_coeff: 0.8732
# 4/4 [==============================] - 0s 2ms/step - loss: 10.8591 - det_coeff: 0.8829
# 12/12 [==============================] - 0s 2ms/step - loss: 79.4486 - det_coeff: -0.0449
# 4/4 [==============================] - 0s 2ms/step - loss: 100.1086 - det_coeff: -0.0256
# 12/12 [==============================] - 0s 2ms/step - loss: 26.1820 - det_coeff: 0.6785
# 4/4 [==============================] - 0s 2ms/step - loss: 36.4924 - det_coeff: 0.6206
# 12/12 [==============================] - 0s 2ms/step - loss: 6.3976 - det_coeff: 0.9105
# 4/4 [==============================] - 0s 2ms/step - loss: 9.6196 - det_coeff: 0.8987
# 12/12 [==============================] - 0s 2ms/step - loss: 95.5504 - det_coeff: -0.2314
# 4/4 [==============================] - 0s 3ms/step - loss: 121.8305 - det_coeff: -0.2566
# 12/12 [==============================] - 0s 2ms/step - loss: 79.4137 - det_coeff: -0.0454
# 4/4 [==============================] - 0s 2ms/step - loss: 99.9636 - det_coeff: -0.0241
# 12/12 [==============================] - 0s 2ms/step - loss: 13.4318 - det_coeff: 0.8199
# 4/4 [==============================] - 0s 3ms/step - loss: 14.1282 - det_coeff: 0.8487
# 12/12 [==============================] - 0s 2ms/step - loss: 81.2216 - det_coeff: -0.0570
# 4/4 [==============================] - 0s 3ms/step - loss: 103.5086 - det_coeff: -0.0614
# 12/12 [==============================] - 0s 2ms/step - loss: 32.0351 - det_coeff: 0.6050
# 4/4 [==============================] - 0s 2ms/step - loss: 44.0484 - det_coeff: 0.5436
# Wall time: 5min 22s

# %%
res.sort_values(by='val_det_coeff', ascending=False).head(20)
# Out:
#      n layers optimizer activation  det_coeff  val_det_coeff
# 84  50      7      adam       relu   0.873804       0.900595
# 90  50     10      adam       relu   0.910458       0.898700
# 78  50      5      adam       relu   0.881320       0.895941
# 72  50      3      adam       relu   0.857101       0.893605
# 66  20     10      adam       relu   0.867114       0.888027
# 87  50      7   RMSprop       relu   0.873240       0.882909
# 75  50      3   RMSprop       relu   0.821293       0.877757
# 63  20      7   RMSprop       relu   0.854420       0.875008
# 69  20     10   RMSprop       relu   0.862395       0.873815
# 60  20      7      adam       relu   0.836463       0.865254
# 54  20      5      adam       relu   0.834327       0.865014
# 81  50      5   RMSprop       relu   0.826730       0.855623
# 57  20      5   RMSprop       relu   0.813559       0.855015
# 39  10      7   RMSprop       relu   0.767354       0.849981
# 93  50     10   RMSprop       relu   0.819936       0.848670
# 48  20      3      adam       relu   0.776375       0.846431
# 51  20      3   RMSprop       relu   0.751740       0.845505
# 42  10     10      adam       relu   0.785577       0.843407
# 45  10     10   RMSprop       relu   0.756407       0.819570
# 30  10      5      adam       relu   0.754523       0.807641

# %%
res[res['optimizer']=='adam'].sort_values(by='val_det_coeff', ascending=False).head(10)
# Out:
#      n layers optimizer activation  det_coeff  val_det_coeff
# 84  50      7      adam       relu   0.873804       0.900595
# 90  50     10      adam       relu   0.910458       0.898700
# 78  50      5      adam       relu   0.881320       0.895941
# 72  50      3      adam       relu   0.857101       0.893605
# 66  20     10      adam       relu   0.867114       0.888027
# 60  20      7      adam       relu   0.836463       0.865254
# 54  20      5      adam       relu   0.834327       0.865014
# 48  20      3      adam       relu   0.776375       0.846431
# 42  10     10      adam       relu   0.785577       0.843407
# 30  10      5      adam       relu   0.754523       0.807641

# %%
res[res['optimizer']=='RMSprop'].sort_values(by='val_det_coeff', ascending=False).head(10)
# Out:
#      n layers optimizer activation  det_coeff  val_det_coeff
# 87  50      7   RMSprop       relu   0.873240       0.882909
# 75  50      3   RMSprop       relu   0.821293       0.877757
# 63  20      7   RMSprop       relu   0.854420       0.875008
# 69  20     10   RMSprop       relu   0.862395       0.873815
# 81  50      5   RMSprop       relu   0.826730       0.855623
# 57  20      5   RMSprop       relu   0.813559       0.855015
# 39  10      7   RMSprop       relu   0.767354       0.849981
# 93  50     10   RMSprop       relu   0.819936       0.848670
# 51  20      3   RMSprop       relu   0.751740       0.845505
# 45  10     10   RMSprop       relu   0.756407       0.819570

# %% [markdown]
# Функция активации relu лучше всех. Большее число нейронов в слоях показывает лучший результат. По количеству слоев закономеронстей не видно. И 5, и 10 слоев достаточно для хорошей метрики. Если посмотреть на лучшие результаты для обоих оптимизаторов, то у adam метрика на валидационных данных выше, но у RMSprop получилось меньше переобучение. На тренировочных данных метрики слабо отличаются.
